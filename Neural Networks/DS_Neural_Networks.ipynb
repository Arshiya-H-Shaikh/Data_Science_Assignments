# %% [markdown]
# **Neural Networks**

# %% [markdown]
# **1. Data Exploration and Preprocessing**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2cc50cd9-4a54-491f-b385-48508ffe8fcd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2cc50cd9-4a54-491f-b385-48508ffe8fcd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('Alphabets_data.csv')
data
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          T     2     8      3       5      1     8    13      0      6
# 1          I     5    12      3       7      2    10     5      5      4
# 2          D     4    11      6       8      6    10     6      2      6
# 3          N     7    11      6       6      3     5     9      4      6
# 4          G     2     1      3       1      1     8     6      6      6
# ...      ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19995      D     2     2      3       3      2     7     7      7      6
# 19996      C     7    10      8       8      4     4     8      6      9
# 19997      T     6     9      6       7      5     6    11      3      7
# 19998      S     2     3      4       2      1     8     7      2      6
# 19999      A     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# ...

# %%
data.head()
# Out:
#   letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  \
# 0      T     2     8      3       5      1     8    13      0      6      6
# 1      I     5    12      3       7      2    10     5      5      4     13
# 2      D     4    11      6       8      6    10     6      2      6     10
# 3      N     7    11      6       6      3     5     9      4      6      4
# 4      G     2     1      3       1      1     8     6      6      6      6
#
#    x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0      10       8      0       8      0       8
# 1       3       9      2       8      4      10
# 2       3       7      3       7      3       9
# 3       4      10      6      10      2       8
# 4       5       9      1       7      5      10

# %%
data.tail()
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 19995      D     2     2      3       3      2     7     7      7      6
# 19996      C     7    10      8       8      4     4     8      6      9
# 19997      T     6     9      6       7      5     6    11      3      7
# 19998      S     2     3      4       2      1     8     7      2      6
# 19999      A     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 19995      6       6       4      2       8      3       7
# 19996     12       9      13      2       9      3       7
# 19997     11       9       5      2      12      2       4
# 19998     10       6       8      1       9      5       8
# 19999      8       1       8      2       7      2       8

# %%
# Convert the "letter	" column from string to float
data['letter'] = data['letter'].astype('category').cat.codes
data
# Out:
#        letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          19     2     8      3       5      1     8    13      0      6
# 1           8     5    12      3       7      2    10     5      5      4
# 2           3     4    11      6       8      6    10     6      2      6
# 3          13     7    11      6       6      3     5     9      4      6
# 4           6     2     1      3       1      1     8     6      6      6
# ...       ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19995       3     2     2      3       3      2     7     7      7      6
# 19996       2     7    10      8       8      4     4     8      6      9
# 19997      19     6     9      6       7      5     6    11      3      7
# 19998      18     2     3      4       2      1     8     7      2      6
# 19999       0     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# ...

# %%
data.shape
# Out:
# (20000, 17)

# %%
data.shape[0]
# Out:
# 20000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  int8
#  1   xbox    20000 non-null  int64
#  2   ybox    20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   xbar    20000 non-null  int64
#  7   ybar    20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybar  20000 non-null  int64
#  12  xy2bar  20000 non-null  int64
#  13  xedge   20000 non-null  int64
#  14  xedgey  20000 non-null  int64
#  15  yedge   20000 non-null  int64
#  16  yedgex  20000 non-null  int64
# dtypes: int64(16), int8(1)
# memory usage: 2.5 MB

# %%
data.describe()
# Out:
#              letter          xbox          ybox         width       height  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.00000
# mean      12.516750      4.023550      7.035500      5.121850      5.37245
# std        7.502175      1.913212      3.304555      2.014573      2.26139
# min        0.000000      0.000000      0.000000      0.000000      0.00000
# 25%        6.000000      3.000000      5.000000      4.000000      4.00000
# 50%       13.000000      4.000000      7.000000      5.000000      6.00000
# 75%       19.000000      5.000000      9.000000      6.000000      7.00000
# max       25.000000     15.000000     15.000000     15.000000     15.00000
#
#               onpix          xbar          ybar         x2bar         y2bar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       3.505850      6.897600      7.500450      4.628600      5.178650
# ...

# %%
# Check for missing values
data.isnull().sum()
# Out:
# letter    0
# xbox      0
# ybox      0
# width     0
# height    0
# onpix     0
# xbar      0
# ybar      0
# x2bar     0
# y2bar     0
# xybar     0
# x2ybar    0
# xy2bar    0
# xedge     0
# xedgey    0
# yedge     0
# yedgex    0
# dtype: int64

# %%
# Separate features and labels
X = data.drop('x2ybar', axis=1)
y = data['x2ybar']

# %%
# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# **2. Model Implementation**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Convert labels to categorical
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)

# %%
# Define a basic ANN model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(y_train_cat.shape[1], activation='softmax')
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train, y_train_cat, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 400/400 [==============================] - 3s 5ms/step - loss: 1.6180 - accuracy: 0.4230 - val_loss: 1.2847 - val_accuracy: 0.5000
# Epoch 2/50
# 400/400 [==============================] - 1s 2ms/step - loss: 1.1973 - accuracy: 0.5309 - val_loss: 1.1592 - val_accuracy: 0.5441
# Epoch 3/50
# 400/400 [==============================] - 1s 2ms/step - loss: 1.0875 - accuracy: 0.5686 - val_loss: 1.0944 - val_accuracy: 0.5594
# Epoch 4/50
# 400/400 [==============================] - 1s 2ms/step - loss: 1.0214 - accuracy: 0.5950 - val_loss: 1.0297 - val_accuracy: 0.5688
# Epoch 5/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.9724 - accuracy: 0.6068 - val_loss: 0.9891 - val_accuracy: 0.5897
# Epoch 6/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.9293 - accuracy: 0.6261 - val_loss: 0.9560 - val_accuracy: 0.6091
# Epoch 7/50
# ...

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test_cat)
print(f"\nTest accuracy: {test_accuracy:.4f}")
# Out:
# 125/125 [==============================] - 0s 3ms/step - loss: 0.7518 - accuracy: 0.6985
#
# Test accuracy: 0.6985

# %% [markdown]
# **3. Hyperparameter Tuning**

# %%
pip install --upgrade tensorflow

# %%
pip install scikeras

# %%
# !pip install --upgrade tensorflow

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Define a function to create the model (required for KerasClassifier)
def create_model(optimizer='adam', activation='relu'):
    model = Sequential([
        Dense(128, activation=activation, input_shape=(X_train.shape[1],)),
        Dense(64, activation=activation),
        Dense(y_train_cat.shape[1], activation='softmax')
    ])
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# Create the KerasClassifier
model = KerasClassifier(build_fn=create_model, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-678616cff5ab> in <cell line: 2>()
#       1 # Create the KerasClassifier
# ----> 2 model = KerasClassifier(build_fn=create_model, verbose=0)
#
# NameError: name 'KerasClassifier' is not defined

# %%
# Define the grid search parameters
param_grid = {
    'optimizer': ['adam', 'sgd'],
    'activation': ['relu', 'tanh'],
    'batch_size': [32, 64],
    'epochs': [50, 100]
}

# %%
# Summarize the results
print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print(f"{mean:.4f} (+/-{std:.4f}) with: {param}")

# %% [markdown]
# **4. Evaluation**

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Evaluate the default model
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test_cat, axis=1)

print("Default model evaluation metrics:")
print(f"Accuracy: {accuracy_score(y_test_classes, y_pred_classes):.4f}")
print(f"Precision: {precision_score(y_test_classes, y_pred_classes, average='weighted'):.4f}")
print(f"Recall: {recall_score(y_test_classes, y_pred_classes, average='weighted'):.4f}")
print(f"F1-score: {f1_score(y_test_classes, y_pred_classes, average='weighted'):.4f}")

# %%
# Evaluate the best model from GridSearchCV
best_model = grid_result.best_estimator_.model
y_pred_best = best_model.predict(X_test)
y_pred_best_classes = np.argmax(y_pred_best, axis=1)

print("\nTuned model evaluation metrics:")
print(f"Accuracy: {accuracy_score(y_test_classes, y_pred_best_classes):.4f}")
print(f"Precision: {precision_score(y_test_classes, y_pred_best_classes, average='weighted'):.4f}")
print(f"Recall: {recall_score(y_test_classes, y_pred_best_classes, average='weighted'):.4f}")
print(f"F1-score: {f1_score(y_test_classes, y_pred_best_classes, average='weighted'):.4f}")
